# %% [markdown]
# # Task:
#
# ### You are required to convert VGG formatted JSON annotations file into COCO format. Additionally you are have to augment that images.

# %%
# Import required Libraries

import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import imutils
import math
import random

# %%
# Changing the directory
import os
os.chdir(r'C:\Users\uzair\Desktop\Computer Vision\cat_dog')
os.getcwd()
# Out:
# 'C:\\Users\\uzair\\Desktop\\Computer Vision\\cat_dog'

# %%
# Opening the given VGG annotation json file
with open('cat_dog_annotations.json', 'r') as f:
    data = json.load(f)

# %%
# Creating a new directory for task
if not os.path.exists('CV_Evaulation_Task'):
    os.makedirs('CV_Evaluation_Task')

# %%
# Initializing the COCO Format
coco = {
    'info': {},
    'licenses': [],
    'images' : [],
    'annotations' : [],
    'categories': []
}

# %%
# Adding the information in info key
coco["info"] = {
    
    "year": 2023,
    "version": 1.0,
    "description": "Dataset in COCO Format",
    "contributor": "Uzair Naeem",
    "url": "ml1.ai",
    "date_created": "Mon Mar 27 2023 00:00:00 GMT+0500 (Pakistan Standard Time)"
}

coco['info']
# Out:
# {'year': 2023,
#  'version': 1.0,
#  'description': 'Dataset in COCO Format',
#  'contributor': 'Uzair Naeem',
#  'url': 'ml1.ai',
#  'date_created': 'Mon Mar 27 2023 00:00:00 GMT+0500 (Pakistan Standard Time)'}

# %%
# Adding the information in license key
license = {
    'id' : 1,
    'name' : 'Unknown',
    'url' : ''
}

coco['licenses'].append(license)

coco['licenses']
# Out:
# [{'id': 1, 'name': 'Unknown', 'url': ''}]

# %%
# Performing augmentation 

image_id = 1
annotation_id = 0
categories = {}
category_id = 1
j = 1

for img_key, img_data in data['_via_img_metadata'].items():
    filename = img_data['filename']
    regions = img_data['regions']
    
    angle = 5
    # Opening the image
    img = cv2.imread(filename)
    # Getting the height and width of image
    height, width = img.shape[:2]
    image_id -= 1
    
    for i in range(72):
        # Defining scale factor between 60 to 100 percent
        scale_factor = np.random.uniform(0.6, 1)
        # Calculating the scaled height and width
        new_height = int(height * scale_factor)
        new_width = int(width * scale_factor)
        # Resizing the image according to scaled factor
        resized_img = cv2.resize(img, (new_width, new_height))
        # Calculating the height and width of resized image for bounding box 
        (img_height, img_width) = resized_img.shape[:2]
        (cx, cy) = (img_width//2, img_height//2)
        # Adding random brightness to image
        contrast = 1
        brightness = random.uniform(1.1, 1.5)
        bright_image = cv2.addWeighted(resized_img, brightness, resized_img, 0, contrast)
        # Performing Rotation of brightened image while preserving the edges
        rot_matrix = cv2.getRotationMatrix2D((cx,cy), i * angle, 1)
        cos = np.abs(rot_matrix[0, 0])
        sin = np.abs(rot_matrix[0, 1])
        nW = int((img_height * sin) + (img_width * cos))
        nH = int((img_height * cos) + (img_width * sin))
        rot_matrix[0, 2] += (nW / 2) - cx
        rot_matrix[1, 2] += (nH / 2) - cy
        rotated_image = cv2.warpAffine(bright_image, rot_matrix, (nW, nH))
        
        # Loop through the regions and draw bounding boxes
        for region in regions:
            shape_attributes = region['shape_attributes']
            region_attributes = region['region_attributes']
            label = list(region_attributes['class'].keys())[0]
            # Extracting x,y, width and height info from the image
            x, y = shape_attributes['x'], shape_attributes['y']
            w, h = shape_attributes['width'], shape_attributes['height']
            
            if label not in categories:
                categories[label] = category_id
                category_id += 1
                
            # Rescaling them according to resized image  
            scaled_x = int(x * scale_factor)
            scaled_y = int(y * scale_factor)
            scaled_w = int(w * scale_factor)
            scaled_h = int(h * scale_factor)
            
            # Calculating the array of four coordinates of bounidng box
            points = np.array([[scaled_x, scaled_y], [scaled_x + scaled_w, scaled_y], [scaled_x + scaled_w, scaled_y + scaled_h], [scaled_x, scaled_y + scaled_h]])
            # Rotating these points according to the rotation angle of image
            rotated_points = np.dot(rot_matrix, np.vstack([points.T, np.ones((1, 4))]))
            # Extracting top left and bottom right coordinates
            min_x = np.min(rotated_points[0])
            max_x = np.max(rotated_points[0])
            min_y = np.min(rotated_points[1])
            max_y = np.max(rotated_points[1])
            # Calculating new width and height of rotated and resized bounding box
            new_x = int(min_x)
            new_y = int(min_y)
            new_w = int(max_x - min_x)
            new_h = int(max_y - min_y)
            # Drawing rectangle for the bounding boxes
            cv2.rectangle(rotated_image, (new_x, new_y), (new_x + new_w, new_y + new_h), (0, 0, 255), 2)

            # Calculating all four coordinates of rotated bounding box for segmentation
            x1, y1 = new_x, new_y
            x2, y2 = new_x + new_w, y1
            x3, y3 = new_x + new_w, new_y + new_h
            x4, y4 = x1, new_y + new_h
            # Segmentation
            segmentation = [x1, y1, x2, y2, x3, y3, x4, y4]
            # Bounding Box
            bbox = [x1, y1, x3, y3]
            # Calculating Area
            area = new_w * new_h
            
            # Annotation key for cooc format
            annotation = {
                
                    'id' : annotation_id,
                    'image_id' : image_id,
                    'category_id' : categories[label],
                    'segmentation' : segmentation,
                    'area' : width * height,
                    'bbox' : bbox,
                    'iscrowd' : 0
                }
            
            coco['annotations'].append(annotation)
            
            annotation_id += 1
        
        # Saving the new augmented image in directory 
        img_name =  f"{j}_{i*angle}degrees.png"
        cv2.imwrite(f"CV_Evaluation_Task/{img_name}", rotated_image)
        
        # Image key for cooc format
        image = {
            'id' : image_id,
            'width' : nW,
            'height' : nH,
            'file_name' : img_name,
            'license' : 1,
            'date_captured': ''
        }
        
        coco['images'].append(image)
        image_id += 1
        
    image_id += 1    
    j += 1
    
    
for cls, id in categories.items():
    coco["categories"].append({
        "id": id,
        "name": cls,
        "supercategory": "class"
    })
    

with open(os.path.join("CV_Evaluation_Task","annotations.json"), "w") as f:
    json.dump(coco, f)

# %%
# Saved COCO format annotation 
with open(r'CV_Evaluation_Task\annotations.json') as f:
    my_data = json.load(f)
    
my_data
# Out:
# {'info': {'year': 2023,
#   'version': 1.0,
#   'description': 'Dataset in COCO Format',
#   'contributor': 'Uzair Naeem',
#   'url': 'ml1.ai',
#   'date_created': 'Mon Mar 27 2023 00:00:00 GMT+0500 (Pakistan Standard Time)'},
#  'licenses': [{'id': 1, 'name': 'Unknown', 'url': ''}],
#  'images': [{'id': 0,
#    'width': 716,
#    'height': 537,
#    'file_name': '1_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 1,
#    'width': 558,
#    'height': 438,
#    'file_name': '1_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 2,
#    'width': 496,
#    'height': 406,
#    'file_name': '1_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 3,
#    'width': 593,
#    'height': 503,
#    'file_name': '1_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 4,
#    'width': 740,
#    'height': 647,
#    'file_name': '1_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 5,
#    'width': 699,
#    'height': 630,
#    'file_name': '1_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 6,
#    'width': 569,
#    'height': 527,
#    'file_name': '1_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 7,
#    'width': 910,
#    'height': 865,
#    'file_name': '1_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 8,
#    'width': 787,
#    'height': 767,
#    'file_name': '1_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 9,
#    'width': 846,
#    'height': 846,
#    'file_name': '1_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 10,
#    'width': 651,
#    'height': 667,
#    'file_name': '1_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 11,
#    'width': 695,
#    'height': 731,
#    'file_name': '1_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 12,
#    'width': 594,
#    'height': 641,
#    'file_name': '1_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 13,
#    'width': 638,
#    'height': 708,
#    'file_name': '1_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 14,
#    'width': 496,
#    'height': 568,
#    'file_name': '1_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 15,
#    'width': 538,
#    'height': 635,
#    'file_name': '1_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 16,
#    'width': 520,
#    'height': 636,
#    'file_name': '1_80degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 17,
#    'width': 570,
#    'height': 726,
#    'file_name': '1_85degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 18,
#    'width': 430,
#    'height': 574,
#    'file_name': '1_90degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 19,
#    'width': 473,
#    'height': 602,
#    'file_name': '1_95degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 20,
#    'width': 405,
#    'height': 495,
#    'file_name': '1_100degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 21,
#    'width': 593,
#    'height': 700,
#    'file_name': '1_105degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 22,
#    'width': 617,
#    'height': 705,
#    'file_name': '1_110degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 23,
#    'width': 648,
#    'height': 719,
#    'file_name': '1_115degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 24,
#    'width': 737,
#    'height': 795,
#    'file_name': '1_120degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 25,
#    'width': 801,
#    'height': 843,
#    'file_name': '1_125degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 26,
#    'width': 602,
#    'height': 617,
#    'file_name': '1_130degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 27,
#    'width': 831,
#    'height': 831,
#    'file_name': '1_135degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 28,
#    'width': 696,
#    'height': 678,
#    'file_name': '1_140degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 29,
#    'width': 559,
#    'height': 532,
#    'file_name': '1_145degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 30,
#    'width': 547,
#    'height': 507,
#    'file_name': '1_150degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 31,
#    'width': 538,
#    'height': 485,
#    'file_name': '1_155degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 32,
#    'width': 577,
#    'height': 505,
#    'file_name': '1_160degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 33,
#    'width': 836,
#    'height': 708,
#    'file_name': '1_165degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 34,
#    'width': 629,
#    'height': 514,
#    'file_name': '1_170degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 35,
#    'width': 580,
#    'height': 456,
#    'file_name': '1_175degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 36,
#    'width': 607,
#    'height': 455,
#    'file_name': '1_180degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 37,
#    'width': 634,
#    'height': 498,
#    'file_name': '1_185degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 38,
#    'width': 565,
#    'height': 462,
#    'file_name': '1_190degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 39,
#    'width': 569,
#    'height': 482,
#    'file_name': '1_195degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 40,
#    'width': 673,
#    'height': 589,
#    'file_name': '1_200degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 41,
#    'width': 805,
#    'height': 725,
#    'file_name': '1_205degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 42,
#    'width': 769,
#    'height': 712,
#    'file_name': '1_210degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 43,
#    'width': 744,
#    'height': 708,
#    'file_name': '1_215degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 44,
#    'width': 823,
#    'height': 803,
#    'file_name': '1_220degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 45,
#    'width': 655,
#    'height': 655,
#    'file_name': '1_225degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 46,
#    'width': 813,
#    'height': 833,
#    'file_name': '1_230degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 47,
#    'width': 692,
#    'height': 728,
#    'file_name': '1_235degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 48,
#    'width': 631,
#    'height': 682,
#    'file_name': '1_240degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 49,
#    'width': 535,
#    'height': 594,
#    'file_name': '1_245degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 50,
#    'width': 554,
#    'height': 633,
#    'file_name': '1_250degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 51,
#    'width': 457,
#    'height': 539,
#    'file_name': '1_255degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 52,
#    'width': 627,
#    'height': 768,
#    'file_name': '1_260degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 53,
#    'width': 500,
#    'height': 636,
#    'file_name': '1_265degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 54,
#    'width': 447,
#    'height': 596,
#    'file_name': '1_270degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 55,
#    'width': 591,
#    'height': 753,
#    'file_name': '1_275degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 56,
#    'width': 414,
#    'height': 507,
#    'file_name': '1_280degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 57,
#    'width': 545,
#    'height': 643,
#    'file_name': '1_285degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 58,
#    'width': 635,
#    'height': 726,
#    'file_name': '1_290degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 59,
#    'width': 645,
#    'height': 715,
#    'file_name': '1_295degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 60,
#    'width': 657,
#    'height': 709,
#    'file_name': '1_300degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 61,
#    'width': 605,
#    'height': 636,
#    'file_name': '1_305degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 62,
#    'width': 610,
#    'height': 626,
#    'file_name': '1_310degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 63,
#    'width': 851,
#    'height': 851,
#    'file_name': '1_315degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 64,
#    'width': 885,
#    'height': 863,
#    'file_name': '1_320degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 65,
#    'width': 724,
#    'height': 689,
#    'file_name': '1_325degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 66,
#    'width': 893,
#    'height': 827,
#    'file_name': '1_330degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 67,
#    'width': 850,
#    'height': 765,
#    'file_name': '1_335degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 68,
#    'width': 541,
#    'height': 474,
#    'file_name': '1_340degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 69,
#    'width': 524,
#    'height': 444,
#    'file_name': '1_345degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 70,
#    'width': 783,
#    'height': 641,
#    'file_name': '1_350degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 71,
#    'width': 521,
#    'height': 409,
#    'file_name': '1_355degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 72,
#    'width': 200,
#    'height': 133,
#    'file_name': '2_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 73,
#    'width': 242,
#    'height': 172,
#    'file_name': '2_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 74,
#    'width': 254,
#    'height': 191,
#    'file_name': '2_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 75,
#    'width': 262,
#    'height': 208,
#    'file_name': '2_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 76,
#    'width': 287,
#    'height': 238,
#    'file_name': '2_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 77,
#    'width': 219,
#    'height': 189,
#    'file_name': '2_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 78,
#    'width': 290,
#    'height': 260,
#    'file_name': '2_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 79,
#    'width': 318,
#    'height': 296,
#    'file_name': '2_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 80,
#    'width': 288,
#    'height': 278,
#    'file_name': '2_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 81,
#    'width': 196,
#    'height': 196,
#    'file_name': '2_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 82,
#    'width': 204,
#    'height': 211,
#    'file_name': '2_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 83,
#    'width': 249,
#    'height': 268,
#    'file_name': '2_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 84,
#    'width': 265,
#    'height': 295,
#    'file_name': '2_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 85,
#    'width': 227,
#    'height': 263,
#    'file_name': '2_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 86,
#    'width': 199,
#    'height': 240,
#    'file_name': '2_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 87,
#    'width': 204,
#    'height': 258,
#    'file_name': '2_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 88,
#    'width': 138,
#    'height': 183,
#    'file_name': '2_80degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 89,
#    'width': 174,
#    'height': 245,
#    'file_name': '2_85degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 90,
#    'width': 139,
#    'height': 209,
#    'file_name': '2_90degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 91,
#    'width': 167,
#    'height': 236,
#    'file_name': '2_95degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 92,
#    'width': 145,
#    'height': 193,
#    'file_name': '2_100degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 93,
#    'width': 220,
#    'height': 277,
#    'file_name': '2_105degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 94,
#    'width': 257,
#    'height': 310,
#    'file_name': '2_110degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 95,
#    'width': 213,
#    'height': 247,
#    'file_name': '2_115degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 96,
#    'width': 250,
#    'height': 278,
#    'file_name': '2_120degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 97,
#    'width': 287,
#    'height': 308,
#    'file_name': '2_125degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 98,
#    'width': 268,
#    'height': 278,
#    'file_name': '2_130degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 99,
#    'width': 216,
#    'height': 216,
#    'file_name': '2_135degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 100,
#    'width': 269,
#    'height': 260,
#    'file_name': '2_140degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 101,
#    'width': 242,
#    'height': 225,
#    'file_name': '2_145degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 102,
#    'width': 323,
#    'height': 290,
#    'file_name': '2_150degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 103,
#    'width': 204,
#    'height': 176,
#    'file_name': '2_155degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 104,
#    'width': 194,
#    'height': 161,
#    'file_name': '2_160degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 105,
#    'width': 265,
#    'height': 210,
#    'file_name': '2_165degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 106,
#    'width': 189,
#    'height': 142,
#    'file_name': '2_170degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 107,
#    'width': 226,
#    'height': 161,
#    'file_name': '2_175degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 108,
#    'width': 237,
#    'height': 158,
#    'file_name': '2_180degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 109,
#    'width': 184,
#    'height': 130,
#    'file_name': '2_185degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 110,
#    'width': 220,
#    'height': 165,
#    'file_name': '2_190degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 111,
#    'width': 266,
#    'height': 210,
#    'file_name': '2_195degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 112,
#    'width': 294,
#    'height': 244,
#    'file_name': '2_200degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 113,
#    'width': 216,
#    'height': 187,
#    'file_name': '2_205degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 114,
#    'width': 262,
#    'height': 235,
#    'file_name': '2_210degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 115,
#    'width': 209,
#    'height': 194,
#    'file_name': '2_215degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 116,
#    'width': 314,
#    'height': 303,
#    'file_name': '2_220degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 117,
#    'width': 322,
#    'height': 322,
#    'file_name': '2_225degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 118,
#    'width': 278,
#    'height': 288,
#    'file_name': '2_230degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 119,
#    'width': 193,
#    'height': 207,
#    'file_name': '2_235degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 120,
#    'width': 213,
#    'height': 238,
#    'file_name': '2_240degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 121,
#    'width': 251,
#    'height': 291,
#    'file_name': '2_245degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 122,
#    'width': 257,
#    'height': 311,
#    'file_name': '2_250degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 123,
#    'width': 170,
#    'height': 215,
#    'file_name': '2_255degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 124,
#    'width': 203,
#    'height': 269,
#    'file_name': '2_260degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 125,
#    'width': 165,
#    'height': 232,
#    'file_name': '2_265degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 126,
#    'width': 123,
#    'height': 185,
#    'file_name': '2_270degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 127,
#    'width': 125,
#    'height': 176,
#    'file_name': '2_275degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 128,
#    'width': 223,
#    'height': 296,
#    'file_name': '2_280degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 129,
#    'width': 228,
#    'height': 289,
#    'file_name': '2_285degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 130,
#    'width': 261,
#    'height': 316,
#    'file_name': '2_290degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 131,
#    'width': 280,
#    'height': 324,
#    'file_name': '2_295degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 132,
#    'width': 293,
#    'height': 326,
#    'file_name': '2_300degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 133,
#    'width': 306,
#    'height': 328,
#    'file_name': '2_305degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 134,
#    'width': 298,
#    'height': 308,
#    'file_name': '2_310degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 135,
#    'width': 290,
#    'height': 290,
#    'file_name': '2_315degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 136,
#    'width': 237,
#    'height': 229,
#    'file_name': '2_320degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 137,
#    'width': 222,
#    'height': 206,
#    'file_name': '2_325degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 138,
#    'width': 287,
#    'height': 258,
#    'file_name': '2_330degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 139,
#    'width': 221,
#    'height': 191,
#    'file_name': '2_335degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 140,
#    'width': 282,
#    'height': 234,
#    'file_name': '2_340degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 141,
#    'width': 220,
#    'height': 174,
#    'file_name': '2_345degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 142,
#    'width': 218,
#    'height': 164,
#    'file_name': '2_350degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 143,
#    'width': 245,
#    'height': 174,
#    'file_name': '2_355degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 144,
#    'width': 295,
#    'height': 147,
#    'file_name': '3_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 145,
#    'width': 302,
#    'height': 169,
#    'file_name': '3_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 146,
#    'width': 300,
#    'height': 186,
#    'file_name': '3_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 147,
#    'width': 335,
#    'height': 226,
#    'file_name': '3_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 148,
#    'width': 348,
#    'height': 254,
#    'file_name': '3_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 149,
#    'width': 324,
#    'height': 253,
#    'file_name': '3_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 150,
#    'width': 313,
#    'height': 261,
#    'file_name': '3_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 151,
#    'width': 349,
#    'height': 310,
#    'file_name': '3_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 152,
#    'width': 270,
#    'height': 255,
#    'file_name': '3_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 153,
#    'width': 301,
#    'height': 301,
#    'file_name': '3_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 154,
#    'width': 213,
#    'height': 226,
#    'file_name': '3_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 155,
#    'width': 293,
#    'height': 330,
#    'file_name': '3_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 156,
#    'width': 271,
#    'height': 324,
#    'file_name': '3_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 157,
#    'width': 276,
#    'height': 353,
#    'file_name': '3_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 158,
#    'width': 162,
#    'height': 222,
#    'file_name': '3_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 159,
#    'width': 222,
#    'height': 328,
#    'file_name': '3_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 160,
#    'width': 191,
#    'height': 308,
#    'file_name': '3_80degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 161,
#    'width': 146,
#    'height': 260,
#    'file_name': '3_85degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 162,
#    'width': 116,
#    'height': 233,
#    'file_name': '3_90degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 163,
#    'width': 132,
#    'height': 234,
#    'file_name': '3_95degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 164,
#    'width': 134,
#    'height': 216,
#    'file_name': '3_100degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 165,
#    'width': 232,
#    'height': 343,
#    'file_name': '3_105degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 166,
#    'width': 240,
#    'height': 329,
#    'file_name': '3_110degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 167,
#    'width': 260,
#    'height': 333,
#    'file_name': '3_115degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 168,
#    'width': 250,
#    'height': 299,
#    'file_name': '3_120degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 169,
#    'width': 238,
#    'height': 268,
#    'file_name': '3_125degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 170,
#    'width': 318,
#    'height': 337,
#    'file_name': '3_130degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 171,
#    'width': 299,
#    'height': 299,
#    'file_name': '3_135degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 172,
#    'width': 221,
#    'height': 209,
#    'file_name': '3_140degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 173,
#    'width': 296,
#    'height': 263,
#    'file_name': '3_145degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 174,
#    'width': 306,
#    'height': 256,
#    'file_name': '3_150degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 175,
#    'width': 280,
#    'height': 219,
#    'file_name': '3_155degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 176,
#    'width': 271,
#    'height': 198,
#    'file_name': '3_160degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 177,
#    'width': 306,
#    'height': 207,
#    'file_name': '3_165degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 178,
#    'width': 243,
#    'height': 150,
#    'file_name': '3_170degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 179,
#    'width': 279,
#    'height': 156,
#    'file_name': '3_175degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 180,
#    'width': 281,
#    'height': 140,
#    'file_name': '3_180degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 181,
#    'width': 277,
#    'height': 155,
#    'file_name': '3_185degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 182,
#    'width': 253,
#    'height': 157,
#    'file_name': '3_190degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 183,
#    'width': 254,
#    'height': 172,
#    'file_name': '3_195degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 184,
#    'width': 211,
#    'height': 154,
#    'file_name': '3_200degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 185,
#    'width': 346,
#    'height': 271,
#    'file_name': '3_205degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 186,
#    'width': 234,
#    'height': 195,
#    'file_name': '3_210degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 187,
#    'width': 296,
#    'height': 263,
#    'file_name': '3_215degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 188,
#    'width': 263,
#    'height': 248,
#    'file_name': '3_220degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 189,
#    'width': 240,
#    'height': 240,
#    'file_name': '3_225degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 190,
#    'width': 287,
#    'height': 305,
#    'file_name': '3_230degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 191,
#    'width': 236,
#    'height': 266,
#    'file_name': '3_235degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 192,
#    'width': 270,
#    'height': 323,
#    'file_name': '3_240degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 193,
#    'width': 246,
#    'height': 315,
#    'file_name': '3_245degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 194,
#    'width': 227,
#    'height': 311,
#    'file_name': '3_250degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 195,
#    'width': 222,
#    'height': 328,
#    'file_name': '3_255degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 196,
#    'width': 193,
#    'height': 311,
#    'file_name': '3_260degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 197,
#    'width': 176,
#    'height': 315,
#    'file_name': '3_265degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 198,
#    'width': 126,
#    'height': 252,
#    'file_name': '3_270degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 199,
#    'width': 153,
#    'height': 273,
#    'file_name': '3_275degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 200,
#    'width': 146,
#    'height': 236,
#    'file_name': '3_280degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 201,
#    'width': 186,
#    'height': 276,
#    'file_name': '3_285degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 202,
#    'width': 195,
#    'height': 267,
#    'file_name': '3_290degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 203,
#    'width': 197,
#    'height': 252,
#    'file_name': '3_295degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 204,
#    'width': 200,
#    'height': 239,
#    'file_name': '3_300degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 205,
#    'width': 244,
#    'height': 275,
#    'file_name': '3_305degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 206,
#    'width': 276,
#    'height': 293,
#    'file_name': '3_310degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 207,
#    'width': 323,
#    'height': 323,
#    'file_name': '3_315degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 208,
#    'width': 254,
#    'height': 240,
#    'file_name': '3_320degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 209,
#    'width': 345,
#    'height': 307,
#    'file_name': '3_325degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 210,
#    'width': 308,
#    'height': 257,
#    'file_name': '3_330degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 211,
#    'width': 349,
#    'height': 273,
#    'file_name': '3_335degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 212,
#    'width': 283,
#    'height': 206,
#    'file_name': '3_340degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 213,
#    'width': 226,
#    'height': 153,
#    'file_name': '3_345degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 214,
#    'width': 249,
#    'height': 154,
#    'file_name': '3_350degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 215,
#    'width': 253,
#    'height': 142,
#    'file_name': '3_355degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 216,
#    'width': 914,
#    'height': 1626,
#    'file_name': '4_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 217,
#    'width': 967,
#    'height': 1561,
#    'file_name': '4_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 218,
#    'width': 1128,
#    'height': 1678,
#    'file_name': '4_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 219,
#    'width': 1109,
#    'height': 1538,
#    'file_name': '4_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 220,
#    'width': 1247,
#    'height': 1623,
#    'file_name': '4_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 221,
#    'width': 1049,
#    'height': 1288,
#    'file_name': '4_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 222,
#    'width': 1555,
#    'height': 1807,
#    'file_name': '4_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 223,
#    'width': 1756,
#    'height': 1939,
#    'file_name': '4_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 224,
#    'width': 1617,
#    'height': 1698,
#    'file_name': '4_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 225,
#    'width': 1270,
#    'height': 1270,
#    'file_name': '4_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 226,
#    'width': 1675,
#    'height': 1594,
#    'file_name': '4_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 227,
#    'width': 1726,
#    'height': 1563,
#    'file_name': '4_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 228,
#    'width': 1774,
#    'height': 1526,
#    'file_name': '4_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 229,
#    'width': 1908,
#    'height': 1555,
#    'file_name': '4_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 230,
#    'width': 1795,
#    'height': 1380,
#    'file_name': '4_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 231,
#    'width': 1488,
#    'height': 1073,
#    'file_name': '4_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 232,
#    'width': 1236,
#    'height': 830,
#    'file_name': '4_80degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 233,
#    'width': 1553,
#    'height': 961,
#    'file_name': '4_85degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 234,
#    'width': 1280,
#    'height': 720,
#    'file_name': '4_90degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 235,
#    'width': 1175,
#    'height': 727,
#    'file_name': '4_95degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 236,
#    'width': 1655,
#    'height': 1112,
#    'file_name': '4_100degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 237,
#    'width': 1862,
#    'height': 1344,
#    'file_name': '4_105degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 238,
#    'width': 1991,
#    'height': 1530,
#    'file_name': '4_110degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 239,
#    'width': 1512,
#    'height': 1232,
#    'file_name': '4_115degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 240,
#    'width': 1763,
#    'height': 1516,
#    'file_name': '4_120degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 241,
#    'width': 1294,
#    'height': 1173,
#    'file_name': '4_125degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 242,
#    'width': 1960,
#    'height': 1866,
#    'file_name': '4_130degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 243,
#    'width': 1717,
#    'height': 1717,
#    'file_name': '4_135degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 244,
#    'width': 1794,
#    'height': 1884,
#    'file_name': '4_140degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 245,
#    'width': 1178,
#    'height': 1301,
#    'file_name': '4_145degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 246,
#    'width': 1468,
#    'height': 1707,
#    'file_name': '4_150degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 247,
#    'width': 1044,
#    'height': 1281,
#    'file_name': '4_155degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 248,
#    'width': 1450,
#    'height': 1886,
#    'file_name': '4_160degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 249,
#    'width': 1172,
#    'height': 1624,
#    'file_name': '4_165degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 250,
#    'width': 1016,
#    'height': 1513,
#    'file_name': '4_170degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 251,
#    'width': 1088,
#    'height': 1758,
#    'file_name': '4_175degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 252,
#    'width': 714,
#    'height': 1270,
#    'file_name': '4_180degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 253,
#    'width': 1098,
#    'height': 1772,
#    'file_name': '4_185degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 254,
#    'width': 1250,
#    'height': 1861,
#    'file_name': '4_190degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 255,
#    'width': 1007,
#    'height': 1395,
#    'file_name': '4_195degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 256,
#    'width': 1265,
#    'height': 1645,
#    'file_name': '4_200degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 257,
#    'width': 1339,
#    'height': 1643,
#    'file_name': '4_205degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 258,
#    'width': 1449,
#    'height': 1685,
#    'file_name': '4_210degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 259,
#    'width': 1415,
#    'height': 1562,
#    'file_name': '4_215degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 260,
#    'width': 1273,
#    'height': 1337,
#    'file_name': '4_220degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 261,
#    'width': 1911,
#    'height': 1911,
#    'file_name': '4_225degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 262,
#    'width': 1929,
#    'height': 1836,
#    'file_name': '4_230degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 263,
#    'width': 1631,
#    'height': 1478,
#    'file_name': '4_235degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 264,
#    'width': 1227,
#    'height': 1056,
#    'file_name': '4_240degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 265,
#    'width': 1990,
#    'height': 1621,
#    'file_name': '4_245degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 266,
#    'width': 1857,
#    'height': 1428,
#    'file_name': '4_250degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 267,
#    'width': 1533,
#    'height': 1106,
#    'file_name': '4_255degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 268,
#    'width': 1493,
#    'height': 1003,
#    'file_name': '4_260degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 269,
#    'width': 1263,
#    'height': 782,
#    'file_name': '4_265degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 270,
#    'width': 1179,
#    'height': 663,
#    'file_name': '4_270degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 271,
#    'width': 1331,
#    'height': 824,
#    'file_name': '4_275degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 272,
#    'width': 1656,
#    'height': 1112,
#    'file_name': '4_280degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 273,
#    'width': 1899,
#    'height': 1370,
#    'file_name': '4_285degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 274,
#    'width': 1793,
#    'height': 1379,
#    'file_name': '4_290degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 275,
#    'width': 1910,
#    'height': 1556,
#    'file_name': '4_295degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 276,
#    'width': 2035,
#    'height': 1751,
#    'file_name': '4_300degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 277,
#    'width': 1596,
#    'height': 1445,
#    'file_name': '4_305degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 278,
#    'width': 1387,
#    'height': 1321,
#    'file_name': '4_310degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 279,
#    'width': 1544,
#    'height': 1544,
#    'file_name': '4_315degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 280,
#    'width': 1806,
#    'height': 1897,
#    'file_name': '4_320degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 281,
#    'width': 1811,
#    'height': 2000,
#    'file_name': '4_325degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 282,
#    'width': 1415,
#    'height': 1644,
#    'file_name': '4_330degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 283,
#    'width': 1160,
#    'height': 1425,
#    'file_name': '4_335degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 284,
#    'width': 1433,
#    'height': 1864,
#    'file_name': '4_340degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 285,
#    'width': 995,
#    'height': 1379,
#    'file_name': '4_345degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 286,
#    'width': 1243,
#    'height': 1849,
#    'file_name': '4_350degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 287,
#    'width': 866,
#    'height': 1399,
#    'file_name': '4_355degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 288,
#    'width': 567,
#    'height': 585,
#    'file_name': '5_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 289,
#    'width': 545,
#    'height': 558,
#    'file_name': '5_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 290,
#    'width': 727,
#    'height': 743,
#    'file_name': '5_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 291,
#    'width': 780,
#    'height': 794,
#    'file_name': '5_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 292,
#    'width': 800,
#    'height': 812,
#    'file_name': '5_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 293,
#    'width': 993,
#    'height': 1004,
#    'file_name': '5_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 294,
#    'width': 886,
#    'height': 894,
#    'file_name': '5_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 295,
#    'width': 781,
#    'height': 785,
#    'file_name': '5_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 296,
#    'width': 994,
#    'height': 997,
#    'file_name': '5_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 297,
#    'width': 1055,
#    'height': 1055,
#    'file_name': '5_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 298,
#    'width': 974,
#    'height': 972,
#    'file_name': '5_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 299,
#    'width': 1014,
#    'height': 1008,
#    'file_name': '5_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 300,
#    'width': 737,
#    'height': 731,
#    'file_name': '5_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 301,
#    'width': 1084,
#    'height': 1072,
#    'file_name': '5_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 302,
#    'width': 1020,
#    'height': 1005,
#    'file_name': '5_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 303,
#    'width': 705,
#    'height': 692,
#    'file_name': '5_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 304,
#    'width': 615,
#    'height': 601,
#    'file_name': '5_80degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 305,
#    'width': 779,
#    'height': 759,
#    'file_name': '5_85degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 306,
#    'width': 631,
#    'height': 612,
#    'file_name': '5_90degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 307,
#    'width': 842,
#    'height': 821,
#    'file_name': '5_95degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 308,
#    'width': 653,
#    'height': 640,
#    'file_name': '5_100degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 309,
#    'width': 805,
#    'height': 791,
#    'file_name': '5_105degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 310,
#    'width': 976,
#    'height': 961,
#    'file_name': '5_110degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 311,
#    'width': 810,
#    'height': 801,
#    'file_name': '5_115degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 312,
#    'width': 903,
#    'height': 896,
#    'file_name': '5_120degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 313,
#    'width': 772,
#    'height': 768,
#    'file_name': '5_125degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 314,
#    'width': 844,
#    'height': 842,
#    'file_name': '5_130degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 315,
#    'width': 750,
#    'height': 750,
#    'file_name': '5_135degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 316,
#    'width': 884,
#    'height': 886,
#    'file_name': '5_140degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 317,
#    'width': 822,
#    'height': 826,
#    'file_name': '5_145degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 318,
#    'width': 848,
#    'height': 855,
#    'file_name': '5_150degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 319,
#    'width': 767,
#    'height': 776,
#    'file_name': '5_155degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 320,
#    'width': 818,
#    'height': 830,
#    'file_name': '5_160degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 321,
#    'width': 803,
#    'height': 817,
#    'file_name': '5_165degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 322,
#    'width': 825,
#    'height': 843,
#    'file_name': '5_170degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 323,
#    'width': 724,
#    'height': 743,
#    'file_name': '5_175degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 324,
#    'width': 747,
#    'height': 771,
#    'file_name': '5_180degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 325,
#    'width': 659,
#    'height': 676,
#    'file_name': '5_185degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 326,
#    'width': 820,
#    'height': 838,
#    'file_name': '5_190degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 327,
#    'width': 774,
#    'height': 787,
#    'file_name': '5_195degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 328,
#    'width': 891,
#    'height': 905,
#    'file_name': '5_200degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 329,
#    'width': 940,
#    'height': 951,
#    'file_name': '5_205degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 330,
#    'width': 895,
#    'height': 902,
#    'file_name': '5_210degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 331,
#    'width': 727,
#    'height': 731,
#    'file_name': '5_215degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 332,
#    'width': 721,
#    'height': 723,
#    'file_name': '5_220degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 333,
#    'width': 1054,
#    'height': 1054,
#    'file_name': '5_225degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 334,
#    'width': 1117,
#    'height': 1114,
#    'file_name': '5_230degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 335,
#    'width': 737,
#    'height': 733,
#    'file_name': '5_235degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 336,
#    'width': 867,
#    'height': 860,
#    'file_name': '5_240degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 337,
#    'width': 989,
#    'height': 978,
#    'file_name': '5_245degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 338,
#    'width': 799,
#    'height': 788,
#    'file_name': '5_250degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 339,
#    'width': 966,
#    'height': 949,
#    'file_name': '5_255degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 340,
#    'width': 858,
#    'height': 840,
#    'file_name': '5_260degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 341,
#    'width': 537,
#    'height': 523,
#    'file_name': '5_265degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 342,
#    'width': 707,
#    'height': 686,
#    'file_name': '5_270degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 343,
#    'width': 549,
#    'height': 535,
#    'file_name': '5_275degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 344,
#    'width': 780,
#    'height': 764,
#    'file_name': '5_280degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 345,
#    'width': 804,
#    'height': 790,
#    'file_name': '5_285degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 346,
#    'width': 676,
#    'height': 665,
#    'file_name': '5_290degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 347,
#    'width': 689,
#    'height': 681,
#    'file_name': '5_295degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 348,
#    'width': 1075,
#    'height': 1066,
#    'file_name': '5_300degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 349,
#    'width': 909,
#    'height': 904,
#    'file_name': '5_305degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 350,
#    'width': 936,
#    'height': 933,
#    'file_name': '5_310degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 351,
#    'width': 750,
#    'height': 750,
#    'file_name': '5_315degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 352,
#    'width': 918,
#    'height': 921,
#    'file_name': '5_320degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 353,
#    'width': 679,
#    'height': 683,
#    'file_name': '5_325degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 354,
#    'width': 827,
#    'height': 834,
#    'file_name': '5_330degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 355,
#    'width': 714,
#    'height': 722,
#    'file_name': '5_335degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 356,
#    'width': 834,
#    'height': 846,
#    'file_name': '5_340degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 357,
#    'width': 802,
#    'height': 816,
#    'file_name': '5_345degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 358,
#    'width': 772,
#    'height': 789,
#    'file_name': '5_350degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 359,
#    'width': 805,
#    'height': 826,
#    'file_name': '5_355degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 360,
#    'width': 372,
#    'height': 248,
#    'file_name': '6_0degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 361,
#    'width': 352,
#    'height': 250,
#    'file_name': '6_5degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 362,
#    'width': 543,
#    'height': 409,
#    'file_name': '6_10degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 363,
#    'width': 481,
#    'height': 380,
#    'file_name': '6_15degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 364,
#    'width': 479,
#    'height': 398,
#    'file_name': '6_20degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 365,
#    'width': 531,
#    'height': 458,
#    'file_name': '6_25degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 366,
#    'width': 383,
#    'height': 344,
#    'file_name': '6_30degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 367,
#    'width': 555,
#    'height': 517,
#    'file_name': '6_35degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 368,
#    'width': 500,
#    'height': 483,
#    'file_name': '6_40degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 369,
#    'width': 559,
#    'height': 559,
#    'file_name': '6_45degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 370,
#    'width': 494,
#    'height': 512,
#    'file_name': '6_50degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 371,
#    'width': 464,
#    'height': 498,
#    'file_name': '6_55degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 372,
#    'width': 537,
#    'height': 598,
#    'file_name': '6_60degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 373,
#    'width': 368,
#    'height': 426,
#    'file_name': '6_65degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 374,
#    'width': 453,
#    'height': 546,
#    'file_name': '6_70degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 375,
#    'width': 287,
#    'height': 362,
#    'file_name': '6_75degrees.png',
#    'license': 1,
#    'date_captured': ''},
#   {'id': 376,
#    'width': 404,
#    'height': 538,
# ...
#    'area': 594000,
#    'bbox': [167, 166, 451, 443],
#    'iscrowd': 0},
#   {'id': 635,
#    'image_id': 461,
#    'category_id': 2,
#    'segmentation': [389, 309, 639, 309, 639, 538, 389, 538],
#    'area': 594000,
#    'bbox': [389, 309, 639, 538],
#    'iscrowd': 0},
#   {'id': 636,
#    'image_id': 462,
#    'category_id': 1,
#    'segmentation': [135, 139, 370, 139, 370, 366, 135, 366],
#    'area': 594000,
#    'bbox': [135, 139, 370, 366],
#    'iscrowd': 0},
#   {'id': 637,
#    'image_id': 462,
#    'category_id': 2,
#    'segmentation': [326, 244, 536, 244, 536, 428, 326, 428],
#    'area': 594000,
#    'bbox': [326, 244, 536, 428],
#    'iscrowd': 0},
#   {'id': 638,
#    'image_id': 463,
#    'category_id': 1,
#    'segmentation': [164, 177, 463, 177, 463, 461, 164, 461],
#    'area': 594000,
#    'bbox': [164, 177, 463, 461],
#    'iscrowd': 0},
#   {'id': 639,
#    'image_id': 463,
#    'category_id': 2,
#    'segmentation': [420, 294, 690, 294, 690, 520, 420, 520],
#    'area': 594000,
#    'bbox': [420, 294, 690, 520],
#    'iscrowd': 0},
#   {'id': 640,
#    'image_id': 464,
#    'category_id': 1,
#    'segmentation': [155, 174, 445, 174, 445, 446, 155, 446],
#    'area': 594000,
#    'bbox': [155, 174, 445, 446],
#    'iscrowd': 0},
#   {'id': 641,
#    'image_id': 464,
#    'category_id': 2,
#    'segmentation': [414, 271, 681, 271, 681, 483, 414, 483],
#    'area': 594000,
#    'bbox': [414, 271, 681, 483],
#    'iscrowd': 0},
#   {'id': 642,
#    'image_id': 465,
#    'category_id': 1,
#    'segmentation': [120, 139, 352, 139, 352, 353, 120, 353],
#    'area': 594000,
#    'bbox': [120, 139, 352, 353],
#    'iscrowd': 0},
#   {'id': 643,
#    'image_id': 465,
#    'category_id': 2,
#    'segmentation': [336, 203, 553, 203, 553, 366, 336, 366],
#    'area': 594000,
#    'bbox': [336, 203, 553, 366],
#    'iscrowd': 0},
#   {'id': 644,
#    'image_id': 466,
#    'category_id': 1,
#    'segmentation': [99, 124, 302, 124, 302, 307, 99, 307],
#    'area': 594000,
#    'bbox': [99, 124, 302, 307],
#    'iscrowd': 0},
#   {'id': 645,
#    'image_id': 466,
#    'category_id': 2,
#    'segmentation': [299, 166, 491, 166, 491, 302, 299, 302],
#    'area': 594000,
#    'bbox': [299, 166, 491, 302],
#    'iscrowd': 0},
#   {'id': 646,
#    'image_id': 467,
#    'category_id': 1,
#    'segmentation': [120, 157, 374, 157, 374, 382, 120, 382],
#    'area': 594000,
#    'bbox': [120, 157, 374, 382],
#    'iscrowd': 0},
#   {'id': 647,
#    'image_id': 467,
#    'category_id': 2,
#    'segmentation': [381, 190, 627, 190, 627, 351, 381, 351],
#    'area': 594000,
#    'bbox': [381, 190, 627, 351],
#    'iscrowd': 0},
#   {'id': 648,
#    'image_id': 468,
#    'category_id': 1,
#    'segmentation': [80, 114, 262, 114, 262, 272, 80, 272],
#    'area': 594000,
#    'bbox': [80, 114, 262, 272],
#    'iscrowd': 0},
#   {'id': 649,
#    'image_id': 468,
#    'category_id': 2,
#    'segmentation': [279, 123, 459, 123, 459, 232, 279, 232],
#    'area': 594000,
#    'bbox': [279, 123, 459, 232],
#    'iscrowd': 0},
#   {'id': 650,
#    'image_id': 469,
#    'category_id': 1,
#    'segmentation': [94, 155, 296, 155, 296, 334, 94, 334],
#    'area': 594000,
#    'bbox': [94, 155, 296, 334],
#    'iscrowd': 0},
#   {'id': 651,
#    'image_id': 469,
#    'category_id': 2,
#    'segmentation': [299, 145, 496, 145, 496, 274, 299, 274],
#    'area': 594000,
#    'bbox': [299, 145, 496, 274],
#    'iscrowd': 0},
#   {'id': 652,
#    'image_id': 470,
#    'category_id': 1,
#    'segmentation': [96, 180, 299, 180, 299, 364, 96, 364],
#    'area': 594000,
#    'bbox': [96, 180, 299, 364],
#    'iscrowd': 0},
#   {'id': 653,
#    'image_id': 470,
#    'category_id': 2,
#    'segmentation': [290, 155, 484, 155, 484, 292, 290, 292],
#    'area': 594000,
#    'bbox': [290, 155, 484, 292],
#    'iscrowd': 0},
#   {'id': 654,
#    'image_id': 471,
#    'category_id': 1,
#    'segmentation': [130, 265, 394, 265, 394, 508, 130, 508],
#    'area': 594000,
#    'bbox': [130, 265, 394, 508],
#    'iscrowd': 0},
#   {'id': 655,
#    'image_id': 471,
#    'category_id': 2,
#    'segmentation': [366, 211, 614, 211, 614, 397, 366, 397],
#    'area': 594000,
#    'bbox': [366, 211, 614, 397],
#    'iscrowd': 0},
#   {'id': 656,
#    'image_id': 472,
#    'category_id': 1,
#    'segmentation': [148, 320, 437, 320, 437, 591, 148, 591],
#    'area': 594000,
#    'bbox': [148, 320, 437, 591],
#    'iscrowd': 0},
#   {'id': 657,
#    'image_id': 472,
#    'category_id': 2,
#    'segmentation': [392, 243, 658, 243, 658, 454, 392, 454],
#    'area': 594000,
#    'bbox': [392, 243, 658, 454],
#    'iscrowd': 0},
#   {'id': 658,
#    'image_id': 473,
#    'category_id': 1,
#    'segmentation': [145, 336, 423, 336, 423, 600, 145, 600],
#    'area': 594000,
#    'bbox': [145, 336, 423, 600],
#    'iscrowd': 0},
#   {'id': 659,
#    'image_id': 473,
#    'category_id': 2,
#    'segmentation': [367, 243, 619, 243, 619, 454, 367, 454],
#    'area': 594000,
#    'bbox': [367, 243, 619, 454],
#    'iscrowd': 0},
#   {'id': 660,
#    'image_id': 474,
#    'category_id': 1,
#    'segmentation': [161, 392, 465, 392, 465, 684, 161, 684],
#    'area': 594000,
#    'bbox': [161, 392, 465, 684],
#    'iscrowd': 0},
#   {'id': 661,
#    'image_id': 474,
#    'category_id': 2,
#    'segmentation': [387, 275, 657, 275, 657, 512, 387, 512],
#    'area': 594000,
#    'bbox': [387, 275, 657, 512],
#    'iscrowd': 0},
#   {'id': 662,
#    'image_id': 475,
#    'category_id': 1,
#    'segmentation': [139, 350, 392, 350, 392, 596, 139, 596],
#    'area': 594000,
#    'bbox': [139, 350, 392, 596],
#    'iscrowd': 0},
#   {'id': 663,
#    'image_id': 475,
#    'category_id': 2,
#    'segmentation': [315, 237, 537, 237, 537, 441, 315, 441],
#    'area': 594000,
#    'bbox': [315, 237, 537, 441],
#    'iscrowd': 0},
#   {'id': 664,
#    'image_id': 476,
#    'category_id': 1,
#    'segmentation': [176, 463, 492, 463, 492, 775, 176, 775],
#    'area': 594000,
#    'bbox': [176, 463, 492, 775],
#    'iscrowd': 0},
#   {'id': 665,
#    'image_id': 476,
#    'category_id': 2,
#    'segmentation': [383, 305, 656, 305, 656, 566, 383, 566],
#    'area': 594000,
#    'bbox': [383, 305, 656, 566],
#    'iscrowd': 0},
#   {'id': 666,
#    'image_id': 477,
#    'category_id': 1,
#    'segmentation': [158, 430, 434, 430, 434, 706, 158, 706],
#    'area': 594000,
#    'bbox': [158, 430, 434, 706],
#    'iscrowd': 0},
#   {'id': 667,
#    'image_id': 477,
#    'category_id': 2,
#    'segmentation': [325, 276, 561, 276, 561, 512, 325, 512],
#    'area': 594000,
#    'bbox': [325, 276, 561, 512],
#    'iscrowd': 0},
#   {'id': 668,
#    'image_id': 478,
#    'category_id': 1,
#    'segmentation': [123, 348, 335, 348, 335, 563, 123, 563],
#    'area': 594000,
#    'bbox': [123, 348, 335, 563],
#    'iscrowd': 0},
#   {'id': 669,
#    'image_id': 478,
#    'category_id': 2,
#    'segmentation': [243, 218, 421, 218, 421, 404, 243, 404],
#    'area': 594000,
#    'bbox': [243, 218, 421, 404],
#    'iscrowd': 0},
#   {'id': 670,
#    'image_id': 479,
#    'category_id': 1,
#    'segmentation': [143, 420, 385, 420, 385, 668, 143, 668],
#    'area': 594000,
#    'bbox': [143, 420, 385, 668],
#    'iscrowd': 0},
#   {'id': 671,
#    'image_id': 479,
#    'category_id': 2,
#    'segmentation': [269, 257, 468, 257, 468, 474, 269, 474],
#    'area': 594000,
#    'bbox': [269, 257, 468, 474],
#    'iscrowd': 0},
#   {'id': 672,
#    'image_id': 480,
#    'category_id': 1,
#    'segmentation': [183, 549, 484, 549, 484, 862, 183, 862],
#    'area': 594000,
#    'bbox': [183, 549, 484, 862],
#    'iscrowd': 0},
#   {'id': 673,
#    'image_id': 480,
#    'category_id': 2,
#    'segmentation': [324, 328, 569, 328, 569, 607, 324, 607],
#    'area': 594000,
#    'bbox': [324, 328, 569, 607],
#    'iscrowd': 0},
#   {'id': 674,
#    'image_id': 481,
#    'category_id': 1,
#    'segmentation': [175, 539, 455, 539, 455, 834, 175, 834],
#    'area': 594000,
#    'bbox': [175, 539, 455, 834],
#    'iscrowd': 0},
#   {'id': 675,
#    'image_id': 481,
#    'category_id': 2,
#    'segmentation': [291, 315, 514, 315, 514, 582, 291, 582],
#    'area': 594000,
#    'bbox': [291, 315, 514, 582],
#    'iscrowd': 0},
#   {'id': 676,
#    'image_id': 482,
#    'category_id': 1,
#    'segmentation': [181, 578, 466, 578, 466, 882, 181, 882],
#    'area': 594000,
#    'bbox': [181, 578, 466, 882],
#    'iscrowd': 0},
#   {'id': 677,
#    'image_id': 482,
#    'category_id': 2,
#    'segmentation': [283, 331, 505, 331, 505, 610, 283, 610],
#    'area': 594000,
#    'bbox': [283, 331, 505, 610],
#    'iscrowd': 0},
#   {'id': 678,
#    'image_id': 483,
#    'category_id': 1,
#    'segmentation': [132, 437, 335, 437, 335, 657, 132, 657],
#    'area': 594000,
#    'bbox': [132, 437, 335, 657],
#    'iscrowd': 0},
#   {'id': 679,
#    'image_id': 483,
#    'category_id': 2,
#    'segmentation': [193, 245, 347, 245, 347, 451, 193, 451],
#    'area': 594000,
#    'bbox': [193, 245, 347, 451],
#    'iscrowd': 0},
#   {'id': 680,
#    'image_id': 484,
#    'category_id': 1,
#    'segmentation': [113, 383, 281, 383, 281, 568, 113, 568],
#    'area': 594000,
#    'bbox': [113, 383, 281, 568],
#    'iscrowd': 0},
#   {'id': 681,
#    'image_id': 484,
#    'category_id': 2,
#    'segmentation': [151, 210, 275, 210, 275, 386, 151, 386],
#    'area': 594000,
#    'bbox': [151, 210, 275, 386],
#    'iscrowd': 0},
#   {'id': 682,
#    'image_id': 485,
#    'category_id': 1,
#    'segmentation': [111, 394, 273, 394, 273, 576, 111, 576],
#    'area': 594000,
#    'bbox': [111, 394, 273, 576],
#    'iscrowd': 0},
#   {'id': 683,
#    'image_id': 485,
#    'category_id': 2,
#    'segmentation': [135, 211, 251, 211, 251, 387, 135, 387],
#    'area': 594000,
#    'bbox': [135, 211, 251, 387],
#    'iscrowd': 0},
#   {'id': 684,
#    'image_id': 486,
#    'category_id': 1,
#    'segmentation': [116, 423, 277, 423, 277, 608, 116, 608],
#    'area': 594000,
#    'bbox': [116, 423, 277, 608],
#    'iscrowd': 0},
#   {'id': 685,
#    'image_id': 486,
#    'category_id': 2,
#    'segmentation': [123, 221, 235, 221, 235, 405, 123, 405],
#    'area': 594000,
#    'bbox': [123, 221, 235, 405],
#    'iscrowd': 0},
#   {'id': 686,
#    'image_id': 487,
#    'category_id': 1,
#    'segmentation': [185, 528, 400, 528, 400, 770, 185, 770],
#    'area': 594000,
#    'bbox': [185, 528, 400, 770],
#    'iscrowd': 0},
#   {'id': 687,
#    'image_id': 487,
#    'category_id': 2,
#    'segmentation': [175, 287, 330, 287, 330, 522, 175, 522],
#    'area': 594000,
#    'bbox': [175, 287, 330, 522],
#    'iscrowd': 0},
#   {'id': 688,
#    'image_id': 488,
#    'category_id': 1,
#    'segmentation': [254, 596, 513, 596, 513, 882, 254, 882],
#    'area': 594000,
#    'bbox': [254, 596, 513, 882],
#    'iscrowd': 0},
#   {'id': 689,
#    'image_id': 488,
#    'category_id': 2,
#    'segmentation': [217, 337, 410, 337, 410, 609, 217, 609],
#    'area': 594000,
#    'bbox': [217, 337, 410, 609],
#    'iscrowd': 0},
#   {'id': 690,
#    'image_id': 489,
#    'category_id': 1,
#    'segmentation': [200, 399, 383, 399, 383, 597, 200, 597],
#    'area': 594000,
#    'bbox': [200, 399, 383, 597],
#    'iscrowd': 0},
#   {'id': 691,
#    'image_id': 489,
#    'category_id': 2,
#    'segmentation': [159, 234, 299, 234, 299, 420, 159, 420],
#    'area': 594000,
#    'bbox': [159, 234, 299, 420],
#    'iscrowd': 0},
#   {'id': 692,
#    'image_id': 490,
#    'category_id': 1,
#    'segmentation': [283, 495, 524, 495, 524, 752, 283, 752],
#    'area': 594000,
#    'bbox': [283, 495, 524, 752],
#    'iscrowd': 0},
#   {'id': 693,
#    'image_id': 490,
#    'category_id': 2,
#    'segmentation': [215, 299, 402, 299, 402, 535, 215, 535],
#    'area': 594000,
#    'bbox': [215, 299, 402, 535],
#    'iscrowd': 0},
#   {'id': 694,
#    'image_id': 491,
#    'category_id': 1,
#    'segmentation': [271, 420, 486, 420, 486, 646, 271, 646],
#    'area': 594000,
#    'bbox': [271, 420, 486, 646],
#    'iscrowd': 0},
#   {'id': 695,
#    'image_id': 491,
#    'category_id': 2,
#    'segmentation': [197, 262, 368, 262, 368, 467, 197, 467],
#    'area': 594000,
#    'bbox': [197, 262, 368, 467],
#    'iscrowd': 0},
#   {'id': 696,
#    'image_id': 492,
#    'category_id': 1,
#    'segmentation': [378, 523, 659, 523, 659, 815, 378, 815],
#    'area': 594000,
#    'bbox': [378, 523, 659, 815],
#    'iscrowd': 0},
#   {'id': 697,
#    'image_id': 492,
#    'category_id': 2,
#    'segmentation': [264, 338, 492, 338, 492, 598, 264, 598],
#    'area': 594000,
#    'bbox': [264, 338, 492, 598],
#    'iscrowd': 0},
#   {'id': 698,
#    'image_id': 493,
#    'category_id': 1,
#    'segmentation': [430, 537, 733, 537, 733, 847, 430, 847],
#    'area': 594000,
#    'bbox': [430, 537, 733, 847],
#    'iscrowd': 0},
#   {'id': 699,
#    'image_id': 493,
#    'category_id': 2,
#    'segmentation': [291, 357, 541, 357, 541, 630, 291, 630],
#    'area': 594000,
#    'bbox': [291, 357, 541, 630],
#    'iscrowd': 0},
#   {'id': 700,
#    'image_id': 494,
#    'category_id': 1,
#    'segmentation': [425, 482, 712, 482, 712, 772, 425, 772],
#    'area': 594000,
#    'bbox': [425, 482, 712, 772],
#    'iscrowd': 0},
#   {'id': 701,
#    'image_id': 494,
#    'category_id': 2,
#    'segmentation': [280, 332, 520, 332, 520, 583, 280, 583],
#    'area': 594000,
#    'bbox': [280, 332, 520, 583],
#    'iscrowd': 0},
#   {'id': 702,
#    'image_id': 495,
#    'category_id': 1,
#    'segmentation': [450, 463, 739, 463, 739, 752, 450, 752],
#    'area': 594000,
#    'bbox': [450, 463, 739, 752],
#    'iscrowd': 0},
#   {'id': 703,
#    'image_id': 495,
#    'category_id': 2,
#    'segmentation': [288, 329, 534, 329, 534, 575, 288, 575],
#    'area': 594000,
#    'bbox': [288, 329, 534, 575],
#    'iscrowd': 0},
#   {'id': 704,
#    'image_id': 496,
#    'category_id': 1,
#    'segmentation': [560, 524, 905, 524, 905, 865, 560, 865],
#    'area': 594000,
#    'bbox': [560, 524, 905, 865],
#    'iscrowd': 0},
#   {'id': 705,
#    'image_id': 496,
#    'category_id': 2,
#    'segmentation': [351, 386, 650, 386, 650, 672, 351, 672],
#    'area': 594000,
#    'bbox': [351, 386, 650, 672],
#    'iscrowd': 0},
#   {'id': 706,
#    'image_id': 497,
#    'category_id': 1,
#    'segmentation': [548, 465, 872, 465, 872, 781, 548, 781],
#    'area': 594000,
#    'bbox': [548, 465, 872, 781],
#    'iscrowd': 0},
#   {'id': 707,
#    'image_id': 497,
#    'category_id': 2,
#    'segmentation': [335, 357, 619, 357, 619, 618, 335, 618],
#    'area': 594000,
#    'bbox': [335, 357, 619, 618],
#    'iscrowd': 0},
#   {'id': 708,
#    'image_id': 498,
#    'category_id': 1,
#    'segmentation': [513, 394, 805, 394, 805, 675, 513, 675],
#    'area': 594000,
#    'bbox': [513, 394, 805, 675],
#    'iscrowd': 0},
#   {'id': 709,
#    'image_id': 498,
#    'category_id': 2,
#    'segmentation': [307, 316, 567, 316, 567, 544, 307, 544],
#    'area': 594000,
#    'bbox': [307, 316, 567, 544],
#    'iscrowd': 0},
#   {'id': 710,
#    'image_id': 499,
#    'category_id': 1,
#    'segmentation': [397, 274, 613, 274, 613, 479, 397, 479],
#    'area': 594000,
#    'bbox': [397, 274, 613, 479],
#    'iscrowd': 0},
#   {'id': 711,
#    'image_id': 499,
#    'category_id': 2,
#    'segmentation': [232, 231, 428, 231, 428, 394, 232, 394],
#    'area': 594000,
#    'bbox': [232, 231, 428, 394],
#    'iscrowd': 0},
#   {'id': 712,
#    'image_id': 500,
#    'category_id': 1,
#    'segmentation': [489, 300, 746, 300, 746, 541, 489, 541],
#    'area': 594000,
#    'bbox': [489, 300, 746, 541],
#    'iscrowd': 0},
#   {'id': 713,
#    'image_id': 500,
#    'category_id': 2,
#    'segmentation': [280, 267, 516, 267, 516, 454, 280, 454],
#    'area': 594000,
#    'bbox': [280, 267, 516, 454],
#    'iscrowd': 0},
#   {'id': 714,
#    'image_id': 501,
#    'category_id': 1,
#    'segmentation': [393, 213, 591, 213, 591, 396, 393, 396],
#    'area': 594000,
#    'bbox': [393, 213, 591, 396],
#    'iscrowd': 0},
#   {'id': 715,
#    'image_id': 501,
#    'category_id': 2,
#    'segmentation': [221, 202, 407, 202, 407, 341, 221, 341],
#    'area': 594000,
#    'bbox': [221, 202, 407, 341],
#    'iscrowd': 0},
#   {'id': 716,
#    'image_id': 502,
#    'category_id': 1,
#    'segmentation': [434, 202, 644, 202, 644, 392, 434, 392],
#    'area': 594000,
#    'bbox': [434, 202, 644, 392],
#    'iscrowd': 0},
#   {'id': 717,
#    'image_id': 502,
#    'category_id': 2,
#    'segmentation': [237, 208, 436, 208, 436, 349, 237, 349],
#    'area': 594000,
#    'bbox': [237, 208, 436, 349],
#    'iscrowd': 0},
#   {'id': 718,
#    'image_id': 503,
#    'category_id': 1,
#    'segmentation': [400, 157, 584, 157, 584, 321, 400, 321],
#    'area': 594000,
#    'bbox': [400, 157, 584, 321],
#    'iscrowd': 0},
#   {'id': 719,
#    'image_id': 503,
#    'category_id': 2,
#    'segmentation': [214, 178, 393, 178, 393, 296, 214, 296],
#    'area': 594000,
#    'bbox': [214, 178, 393, 296],
#    'iscrowd': 0}],
#  'categories': [{'id': 1, 'name': 'dog', 'supercategory': 'class'},
#   {'id': 2, 'name': 'cat', 'supercategory': 'class'}]}
