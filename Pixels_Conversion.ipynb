# %%
import os
os.getcwd()
os.chdir(r'C:\Users\uzair\Desktop\New folder')
os.getcwd()
# Out:
# 'C:\\Users\\uzair\\Desktop\\New folder'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'baboon.png', 'Untitled.ipynb']

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
#      ---------------------------------------- 38.2/38.2 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in c:\users\uzair\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np

# img = cv2.imread('baboon.png')
# img = cv2.imread('image.png')
img = cv2.imread('image_1.png')

l_red = np.array([0, 50, 50])
u_red = np.array([10, 255, 255])


hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


mask = cv2.inRange(hsv, l_red, u_red)


img[mask > 0] = [0, 0, 0]


cv2.imshow('Modified Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# import numpy as np
# import cv2
# img = cv2.imread('baboon.png')
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

# img = cv2.imread('baboon.png')
# b,g,r = cv2.split(img)
# img2 = cv2.merge([r,g,b])
# plt.subplot(121);plt.imshow(img) # expects distorted color
# plt.subplot(122);plt.imshow(img2) # expect true color
# plt.show()

# cv2.imshow('bgr image',img) # expects true color
# cv2.imshow('rgb image',img2) # expects distorted color
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np

# baboon = cv2.imread('baboon.png')
# baboobtest = baboon

# px = baboon[100,500]
# print (px)

# # accessing only blue pixel
# blue = baboon[100,500,0]
# print (blue)
# Out:
# [147 177 159]
# 147

# %% [markdown]
# ###### Create a little 10x1 numpy array and make the first pixel red, the second orange, then yellow, green, blue, indigo, violet then black, mid-grey and white.

# %%
# import numpy as np
# import imageio
# import cv2

# # Create black image 10x1
# im = np.zeros([1,10,3], dtype=np.uint8)
# print(im)

# # Fill with colours of rainbow and greys
# im[0,0,:]=[255,0,0]       # red
# im[0,1,:]=[255,165,0]     # orange
# im[0,2,:]=[255,255,0]     # yellow
# im[0,3,:]=[0,255,0]       # green
# im[0,4,:]=[0,0,255]       # blue
# im[0,5,:]=[75,0,130]      # indigo
# im[0,6,:]=[238,130,238]   # violet
# im[0,7,:]=[0,0,0]         # black
# im[0,8,:]=[127,127,127]   # grey
# im[0,9,:]=[255,255,255]   # white
# imageio.imwrite("result.png",im)

# hsv=cv2.cvtColor(im,cv2.COLOR_RGB2HSV)
# print(hsv)
